# %% [raw]
# ---
# layout: post
# title: All Homeworks
# description: All Homeworks
# categories: [Javascript, Homework]
# permalink: /allhwhi
# author: Krish K
# codemirror: true
# ---

# %% [markdown]
# ## Strings

# %%
# %%js
#
# // GAME_RUNNER: Peppa Pig Boss Battle + Music API | hide_edit: true, width: 100%, height: 600px
#
# import GameLeveltest from '/assets/js/GameEnginev1/Gameleveltest.js';
# import PeppaMusic from '/assets/js/GameEnginev1/PeppaMusic.js';
#
# const peppaMusicApi = new PeppaMusic();
# peppaMusicApi.addGestureListeners();
#
# export const gameLevelClasses = [GameLeveltest];
# export { GameControl };
