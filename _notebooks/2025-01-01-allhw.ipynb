# %% [raw]
# ---
# layout: post
# title: All Homeworks
# description: All Homeworks
# categories: [Javascript, Homework]
# permalink: /allhw
#
# author: Krish K
# codemirror: true
# ---

# %% [markdown]
# ## Level 1

# %% [markdown]
# This level is the first level in our game. It is purely for plot purposes. There is no way to die in this level. In this level, there are 4 key things to note. The first of these is the background. The background of the level indicates that we are on Earth. This is important for later purposes. The second key thing to notice is that the player is an astronaut. This indicates that we might be traveling to space. The third key thing id the first npc. He give you a mission to see if another planet is worth living on. The last noticeable thing in this level is the second npc. He tells you to board and then 1.5 seconds later, you move on.

# %%
# %%js
#
# // GAME_RUNNER: Transition between water and fish parallax levels using the ESC key.
#
# import GameControl from "/assets/js/GameEnginev1/essentials/GameControl.js";
# import GameEnvBackground from '/assets/js/GameEnginev1/essentials/GameEnvBackground.js';
# import Player from '/assets/js/GameEnginev1/essentials/Player.js';
# import Npc from '/assets/js/GameEnginev1/essentials/Npc.js';
# import Barrier from '/assets/js/GameEnginev1/essentials/Barrier.js';
#
# class GameLevelprologue {
#     constructor(gameEnv) {
#         const path = gameEnv.path;
#         const width = gameEnv.innerWidth;
#         const height = gameEnv.innerHeight;
#
#         // Floor is roughly 58% down the canvas based on the background image
#         const floorY = Math.floor(height * 0.72);
#
#         const bgData = {
#             name: "custom_bg",
#             src: path + "/images/gamebuilder/bg/newgamebg.jpeg",
#             pixels: { height: 720, width: 1280 }
#         };
#
#         const playerData = {
#             id: 'playerData',
#             src: path + "/images/gamebuilder/sprites/astro.png",
#             SCALE_FACTOR: 5,
#             STEP_FACTOR: 1000,
#             ANIMATION_RATE: 50,
#             // height/SCALE_FACTOR = rendered height; subtract from floorY to place feet on floor
#             INIT_POSITION: { x: 100, y: floorY - Math.floor(height / 5) },
#             pixels: { height: 770, width: 513 },
#             orientation: { rows: 4, columns: 4 },
#             down: { row: 0, start: 0, columns: 3 },
#             downRight: { row: 1, start: 0, columns: 3 },
#             downLeft: { row: 2, start: 0, columns: 3 },
#             right: { row: 1, start: 0, columns: 3 },
#             left: { row: 2, start: 0, columns: 3 },
#             up: { row: 3, start: 0, columns: 3 },
#             upRight: { row: 1, start: 0, columns: 3 },
#             upLeft: { row: 2, start: 0, columns: 3 },
#             hitbox: { widthPercentage: 0, heightPercentage: 0 },
#             keypress: { up: 87, left: 65, down: 83, right: 68 }
#         };
#
#         const npcData1 = {
#             id: 'guy',
#             greeting: 'Hi Astro. You are being sent on a mission to see if planet - B34FG is save to live on. Good luck.',
#             src: path + "/images/gamify/chillguy.png",
#             SCALE_FACTOR: 8,
#             ANIMATION_RATE: 50,
#             INIT_POSITION: { x: 500, y: floorY - Math.floor(height / 8) },
#             pixels: { height: 512, width: 384 },
#             orientation: { rows: 4, columns: 3 },
#             down: { row: 0, start: 0, columns: 3 },
#             right: { row: Math.min(1, 4 - 1), start: 0, columns: 3 },
#             left: { row: Math.min(2, 4 - 1), start: 0, columns: 3 },
#             up: { row: Math.min(3, 4 - 1), start: 0, columns: 3 },
#             upRight: { row: Math.min(3, 4 - 1), start: 0, columns: 3 },
#             downRight: { row: Math.min(1, 4 - 1), start: 0, columns: 3 },
#             upLeft: { row: Math.min(2, 4 - 1), start: 0, columns: 3 },
#             downLeft: { row: 0, start: 0, columns: 3 },
#             hitbox: { widthPercentage: 0.1, heightPercentage: 0.2 },
#             dialogues: ['Hi Astro. You are being sent on a mission to see if planet - B34FG is save to live on. Good luck. Also, nice moonwalk!'],
#             reaction: function() { if (this.dialogueSystem) { this.showReactionDialogue(); } else { console.log(this.greeting); } },
#             interact: function() { if (this.dialogueSystem) { this.showRandomDialogue(); } }
#         };
#
#         const npcData2 = {
#             id: 'ship',
#             greeting: 'BORADING NOW.',
#             src: path + "/images/gamebuilder/sprites/pew.png",
#             SCALE_FACTOR: 8,
#             ANIMATION_RATE: 50,
#             INIT_POSITION: { x: 679, y: floorY - Math.floor(height / 8) },
#             pixels: { height: 320, width: 320 },
#             orientation: { rows: 4, columns: 4 },
#             down: { row: 0, start: 0, columns: 3 },
#             right: { row: Math.min(1, 4 - 1), start: 0, columns: 3 },
#             left: { row: Math.min(2, 4 - 1), start: 0, columns: 3 },
#             up: { row: Math.min(3, 4 - 1), start: 0, columns: 3 },
#             upRight: { row: Math.min(3, 4 - 1), start: 0, columns: 3 },
#             downRight: { row: Math.min(1, 4 - 1), start: 0, columns: 3 },
#             upLeft: { row: Math.min(2, 4 - 1), start: 0, columns: 3 },
#             downLeft: { row: 0, start: 0, columns: 3 },
#             hitbox: { widthPercentage: 0.1, heightPercentage: 0.2 },
#             dialogues: ['BORADING NOW.'],
#             reaction: function() { if (this.dialogueSystem) { this.showReactionDialogue(); } else { console.log(this.greeting); } },
#             interact: function() {
#                 if (this.dialogueSystem) { this.showRandomDialogue(); }
#                 setTimeout(() => {
#                     if (this.gameEnv?.gameControl?.currentLevel) {
#                         this.gameEnv.gameControl.currentLevel.continue = false;
#                     }
#                 }, 1500);
#             }
#         };
#
#         this.classes = [
#             { class: GameEnvBackground, data: bgData },
#             { class: Player, data: playerData },
#             { class: Npc, data: npcData1 },
#             { class: Npc, data: npcData2 }
#         ];
#
#         /* BUILDER_ONLY_START */
#         try {
#             setTimeout(() => {
#                 try {
#                     const objs = Array.isArray(gameEnv?.gameObjects) ? gameEnv.gameObjects : [];
#                     const summary = objs.map(o => ({ cls: o?.constructor?.name || 'Unknown', id: o?.canvas?.id || '', z: o?.canvas?.style?.zIndex || '' }));
#                     if (window && window.parent) window.parent.postMessage({ type: 'rpg:objects', summary }, '*');
#                 } catch (_) {}
#             }, 250);
#         } catch (_) {}
#         try {
#             if (window && window.parent) {
#                 try {
#                     const rect = (gameEnv && gameEnv.container && gameEnv.container.getBoundingClientRect) ? gameEnv.container.getBoundingClientRect() : { top: gameEnv.top || 0, left: 0 };
#                     window.parent.postMessage({ type: 'rpg:env-metrics', top: rect.top, left: rect.left }, '*');
#                 } catch (_) {
#                     try { window.parent.postMessage({ type: 'rpg:env-metrics', top: gameEnv.top, left: 0 }, '*'); } catch (__){ }
#                 }
#             }
#         } catch (_) {}
#         try {
#             window.addEventListener('message', (e) => {
#                 if (!e || !e.data) return;
#                 if (e.data.type === 'rpg:toggle-walls') {
#                     const show = !!e.data.visible;
#                     if (Array.isArray(gameEnv?.gameObjects)) {
#                         for (const obj of gameEnv.gameObjects) {
#                             if (obj instanceof Barrier) {
#                                 obj.visible = show;
#                             }
#                         }
#                     }
#                 } else if (e.data.type === 'rpg:set-drawn-barriers') {
#                     const arr = Array.isArray(e.data.barriers) ? e.data.barriers : [];
#                     window.__overlayBarriers = window.__overlayBarriers || [];
#                     try {
#                         for (const ob of window.__overlayBarriers) {
#                             if (ob && typeof ob.destroy === 'function') ob.destroy();
#                         }
#                     } catch (_) {}
#                     window.__overlayBarriers = [];
#                     for (const bd of arr) {
#                         try {
#                             const data = {
#                                 id: bd.id,
#                                 x: bd.x,
#                                 y: bd.y,
#                                 width: bd.width,
#                                 height: bd.height,
#                                 visible: !!bd.visible,
#                                 hitbox: { widthPercentage: 0.0, heightPercentage: 0.0 },
#                                 fromOverlay: true
#                             };
#                             const bobj = new Barrier(data, gameEnv);
#                             gameEnv.gameObjects.push(bobj);
#                             window.__overlayBarriers.push(bobj);
#                         } catch (_) {}
#                     }
#                 }
#             });
#         } catch (_) {}
#         /* BUILDER_ONLY_END */
#     }
# }
#
# export const gameLevelClasses = [GameLevelprologue];
# export default GameLevelprologue;

# %% [markdown]
# ## Level 2: Meteors

# %% [markdown]
# This next level is the hardest level in the game. When you first spawn in, you will notice 3 things. The first of these is the badckground. the background indicates that we are on the way to the new planet. The next thing you'll notice is the player. the player s the ship from the previous level, showing that we are on our way. The last first thing you'll notice is the ufo sprite on the right. this is the enemy. When talking to him, he'll summon metoers that will fly at you from the right. Also, a one minute survival timer will start on the right. Then it reaches zero and you haven't died, you get to move on the to next level.

# %%
# %%js
#
# // GAME_RUNNER: Transition between water and fish parallax levels using the ESC key.
#
# import GameControl from "/assets/js/GameEnginev1/essentials/GameControl.js";
# import GameLeveltest from "/assets/js/GameEnginev1/GameLeveltest.js";
# export const gameLevelClasses = [GameLeveltest];
# export { GameControl };

# %% [markdown]
# ## Missing Plot Level 1

# %% [markdown]
# After this level, there was supposed to be another plot leve;. However, we ran out of time and never fully got around to it. This is what would have happened: You find an AI floating in space. When talked to, he says that he must destroy you and strips you of your ship. Then he sends you flying to a random nearby planet. This level serves as a segway into the next major level in the game: the maze.

# %% [markdown]
# ## Level 4: The Maze

# %% [markdown]
# The next level has a massive maze that the player must solve in order to continue. In the maze, there are landmines that when stepped on, explode you with a brand new death screen. After the death screen disappears, you have to restart the whole game. This means you have to be careful. Then, once you reach the npc at the end, if you talk to him, he'll give you anotjher ship to go back home with.

# %% [markdown]
# ## Level 5 The finale

# %% [markdown]
# This si the final level. In this level, you are back in space and you find the same AI again. When talked to, he tells you that you must die. After a few seconds, a homing meteor spawns that is impossible to dodge. the game ends with the player dying and never returning home. This game is meant to teach people that not everything has a happy ending and that sometimes, we have to live with a bad one.

# %% [markdown]
# ## To Do
#
# This game is far from finished. We still have things to do. This includes the missing story levels, better sprites, better animations, some form of leaderboard, collectibles in the maze, and maybe extra levels. Stay tuned to game mre!

# %% [markdown]
# ## Credits:
#
# Designer: Krish K
# Manager: Krish K
# Prologue: Krish K
# Level 2: Krish K
# Level 3: Aarnav J
# Level 4: Jasan B
# Technician: Jasan B
# Scrum Master: Aarnav J
